# %% [markdown]
# # Tugas 1

# %% [markdown]
# Nama		: Syifa Firnanda
#
# NIM		    : 121450094
#
# Prodi		: Sains Data
#
# Kelas		: RB
#
# Mata Kuliah	: Pemrograman Berbasis Fungsi

# %% [markdown]
# ## 1. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan object oriented (minimal 3)!
#
# Jawab:

# %% [markdown]
# ![Tugas%201%20PBF%20PDF_page-0001.jpg](attachment:Tugas%201%20PBF%20PDF_page-0001.jpg)

# %% [markdown]
# ## 2.	Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma object oriented dibandingkan dengan functional (minimal 3) !
#
# Jawab:

# %% [markdown]
# ![Tugas%201%20PBF%20PDF_page-0002.jpg](attachment:Tugas%201%20PBF%20PDF_page-0002.jpg)

# %% [markdown]
# ## 3.	Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan functional (minimal 3) !
#
# Jawab:

# %% [markdown]
# ![Tugas%201%20PBF%20PDF_page-0003.jpg](attachment:Tugas%201%20PBF%20PDF_page-0003.jpg)

# %% [markdown]
# ## 4.	Apa yang dimaksud dengan pure functional programming language?
#
# Jawab:

# %% [markdown]
# Pure functional programming language merupakan bahasa pemrograman yang hanya dipengaruhi oleh parameter yang diinputkan, tidak menghasilkan output lain di luar fungsi, dan tidak mempengaruhi operasi fungsi. Pure fungtional akan tetap menghasilkan output yang sama ketika dipanggil sebanyak apapun dengan suatu inputan karena kemurnian dari inputan tersebut tetap dipertahankan agar dapat menghasilkan output sesuai yang diinginkan.

# %% [markdown]
# ## 5. Dari bahasa pemrograman FP di slide sebelumnya (slide 14), manakah yang termasuk pure functional programming language?
#
# Jawab:

# %% [markdown]
# Bahasa pemrograman FP pada slide sebelumnya yang termasuk Pure functional programming language adalah Haskell.

# %% [markdown]
# ## 6. Membuat program Simple Password encryption, dengan ketentuan

# %% [markdown]
# 1. Input password bertipe string dengan batasan panjang password 100 karakter
#
# 2. Setiap karakter dari string tersebut diubah menjadi ASCII value
#
# 3. Kemudian setiap ASCII value tersebut dikembangkan menjadi 3 value dengan dilakukan operasi berikut:
#
#
# - Value pertama dibagi dengan integer 26 kemudian dibulatkan dan dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter
#
# - Value kedua dihitung sisa bagi dengan 26 kemudian dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter
#
# - Value ketiga adalah karakter ‘+’ jika value pertama lebih besar dari value kedua, atau value ketiga adalah karakter ‘-’ jika value pertama tidak lebih besar dari value kedua
#
#
# 4. Deretan value pertama, kedua dan ketiga untuk setiap karakter dalam password tersebut sehingga didapatkan password dalam bentuk baru

# %%
# membuat fungsi enkripsi
def encryp(my_pass):
    # batasan untuk jumlah karakter password
    if len(my_pass) > 100:
        print("Please enter 1-100 characters")
    
    encryp_my_pass=""
    for char in my_pass:
        value_ascii = ord(char)
        # membuat value pertama
        value1 = round((value_ascii // 26)) + 80
        # membuat value kedua
        value2 = (value_ascii % 26) + 80
        # membuat value ketiga
        value3 = '+' if value1 > value2 else '-'
        # menggabungkan seluruh value
        encryp_my_pass += chr(value1) + chr(value2) + value3
    print("The encryption password is:", encryp_my_pass)

# %%
# enkripsi password sesuai inputan user
real_pass = input("Enter your password: ")
encryp(real_pass)
